# %% [markdown]
# # Text Encryption using Play Fair Algorithm

# %% [markdown]
# ### Generating an Encryption key

# %%
a=input("Enter key you want to use for encryption. It can be any combination of English alphabets or mathematical numerical value (max-length should be 36 chars): ")
b="abcdefghijklmnopqrstuvwxyz0123456789"
c=[]
for i in range(len(a)):
    if a[i] not in c:
        c.append(a[i])
for j in range(len(b)):
    if b[j] not in a:
        c.append(b[j])
d=[]
for i in range(0,35,6):
    d.append(c[i:i+6])

# %% [markdown]
# ### Encrypting a text using the above provided key

# %%
def search(char,d):
    for i in range(0,6):
        for j in range(0,6):
            if d[i][j]==char:
                return i,j

n=input("Enter the text (in lowercase) you want to encrypt: ")
l=0
m=0
p=""
while(m<len(n)):
    if m==len(n)-1:
        p+=n[m]
    else:
        q,r,s,t=search(n[m],d)[0],search(n[m],d)[1],search(n[m+1],d)[0],search(n[m+1],d)[1]
        if n[m]==n[m+1]:
            p=p+n[m]+"@"

        elif q==s:
            p=p+d[q][(r+1)%6]+d[s][(t+1)%6]

        elif r==t:
            p=p+d[(q+1)%6][r]+d[(s+1)%6][t]

        else:
            p=p+d[q][t]+d[s][r]
    m=m+2
        
print("Encrypted message: "+ p)
# Out:
# Encrypted message: 7

# %% [markdown]
# ### Decrypting the encrypted message using the key provided

# %%
n=p
m=0
p=""
while(m<len(n)):
    if m==len(n)-1:
        p+=n[m]
    elif n[m]=="@" or n[m+1]=="@":
        if n[m]!="@":
            p+=n[m]+n[m]
            
        else:
            p+=n[m+1]+n[m+1]
            
    else:
        q,r,s,t=search(n[m],d)[0],search(n[m],d)[1],search(n[m+1],d)[0],search(n[m+1],d)[1]
    
        if q==s:
            p=p+d[q][(r-1)%6]+d[s][(t-1)%6]
            
        elif r==t:
            p=p+d[(q-1)%6][r]+d[(s-1)%6][t]
            
        else:
            p=p+d[q][t]+d[s][r]
    m=m+2
        
print("Decrypted message: "+p)
# Out:
# Decrypted message: 7

# %% [markdown]
# # Image Encryption

# %% [markdown]
# ### Image Input

# %%
import matplotlib.pyplot as plt,numpy as np,random
from numpy import zeros
#Enter the address of the image inside r""
#Enter a jpg image.
img=plt.imread(r"C://Users/sadan/download_1.jpg")

rows=img.shape[0]
col=img.shape[1]

plt.title("Original Image")
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 from numpy import zeros
#       3 #Enter the address of the image inside r""
#       4 #Enter a jpg image.
# ----> 5 img=plt.imread(r"C://Users/sadan/download_1.jpg")
#       7 rows=img.shape[0]
#       8 col=img.shape[1]
#
# File c:\Users\Ankit\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2613, in imread(fname, format)
#    2609 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2610 def imread(
#    2611         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2612 ) -> np.ndarray:
# -> 2613     return matplotlib.image.imread(fname, format)
#
# File c:\Users\Ankit\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\image.py:1502, in imread(fname, format)
#    1495 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1496     # Pillow doesn't handle URLs directly.
#    1497     raise ValueError(
#    1498         "Please open the URL for reading and pass the "
#    1499         "result to Pillow, e.g. with "
#    1500         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1501         )
# -> 1502 with img_open(fname) as image:
#    1503     return (_pil_png_to_float_array(image)
#    1504             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1505             pil_to_array(image))
#
# File c:\Users\Ankit\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:3469, in open(fp, mode, formats)
#    3466     filename = os.path.realpath(os.fspath(fp))
#    3468 if filename:
# -> 3469     fp = builtins.open(filename, "rb")
#    3470     exclusive_fp = True
#    3471 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\sadan\\download_1.jpg'

# %% [markdown]
# ### Generating Key

# %%
#Here I had generated a key with the help og random values. You can skip this step and provide your own key below.
key=[]
while len(key)!=256:
    j=random.randrange(0,256)
    if j not in key:
        key.append(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 key=[]
#       3 while len(key)!=256:
# ----> 4     j=random.randrange(0,256)
#       5     if j not in key:
#       6         key.append(j)
#
# NameError: name 'random' is not defined

# %% [markdown]
# ### Encrypt Image

# %%
#You can enter your own key in form of a list of randomly arranged numbers from 0 to 255.
#key=[]

def encrypt_image(img, key, rows, col):
    img1=np.zeros((rows,col,3),dtype=int)
    for i in range(rows):
        for j in range(col):
            for k in range(3):
                img1[i][j][k]=key[img[i][j][k]]
    return img1

img1=encrypt_image(img,key,rows,col)
plt.title("Encrypted Image")
plt.imshow(img1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       9                 img1[i][j][k]=key[img[i][j][k]]
#      10     return img1
# ---> 12 img1=encrypt_image(img,key,rows,col)
#      13 plt.title("Encrypted Image")
#      14 plt.imshow(img1)
#
# NameError: name 'img' is not defined

# %% [markdown]
# ### Decrypt above encrypted image

# %%
def decrypt_image(img,key, rows, col):
    img1=np.zeros((rows,col,3),dtype=int)
    for i in range(rows):
        for j in range(col):
            for k in range(3):
                img1[i][j][k]=key.index(img[i][j][k])
    return img1

img3=decrypt_image(img1,key,rows,col)
plt.title("Decrypted Image")
plt.imshow(img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6                 img1[i][j][k]=key.index(img[i][j][k])
#       7     return img1
# ----> 9 img3=decrypt_image(img1,key,rows,col)
#      10 plt.title("Decrypted Image")
#      11 plt.imshow(img3)
#
# NameError: name 'img1' is not defined
